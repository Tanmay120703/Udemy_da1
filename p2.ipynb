# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\Admim\AppData\Local\Temp\ipykernel_10184\555797462.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv("D:\\datasets\\udemy_courses.csv")

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.tail()
# Out:
#       course_id                                       course_title  \
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3673  https://www.udemy.com/easy-jquery-for-beginner...     True    100
# 3674  https://www.udemy.com/how-to-make-a-wordpress-...     True     25
# 3675  https://www.udemy.com/learn-and-build-using-po...     True     40
# 3676  https://www.udemy.com/css-animations-create-am...     True     50
# 3677  https://www.udemy.com/using-modx-cms-to-build-...     True     45
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.shape
# Out:
# (3678, 12)

# %%
df.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
df.subject.unique()
# Out:
# array(['Business Finance', 'Graphic Design', 'Musical Instruments',
#        'Web Development'], dtype=object)

# %%
df.subject.value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
df[df.is_paid == False].sum()
# Out:
# course_id                                                      214348561
# course_title           Options Trading 101: The BasicsStock Market In...
# url                    https://www.udemy.com/options-trading-101-the-...
# is_paid                                                                0
# price                                                                  0
# num_subscribers                                                  3575525
# num_reviews                                                       132038
# num_lectures                                                        6639
# level                  Beginner LevelBeginner LevelAll LevelsAll Leve...
# content_duration                                              685.333333
# published_timestamp    2017-03-23T22:19:57Z2013-12-25T19:53:34Z2014-0...
# subject                Business FinanceBusiness FinanceBusiness Finan...
# dtype: object

# %%
df[df.is_paid == False].count()
# Out:
# course_id              310
# course_title           310
# url                    310
# is_paid                310
# price                  310
# num_subscribers        310
# num_reviews            310
# num_lectures           310
# level                  310
# content_duration       310
# published_timestamp    310
# subject                310
# dtype: int64

# %%
df[df.is_paid == True].count()
# Out:
# course_id              3368
# course_title           3368
# url                    3368
# is_paid                3368
# price                  3368
# num_subscribers        3368
# num_reviews            3368
# num_lectures           3368
# level                  3368
# content_duration       3368
# published_timestamp    3368
# subject                3368
# dtype: int64

# %%
df.groupby('level') ['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64

# %%
df.sort_values(by = 'num_subscribers' , ascending = False).head(5)
# Out:
#       course_id                                       course_title  \
# 2827      41295               Learn HTML5 Programming From Scratch
# 3032      59014                     Coding for Entrepreneurs Basic
# 3230     625204                         The Web Developer Bootcamp
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...
# 3232     764164              The Complete Web Developer Course 2.0
#
#                                                     url  is_paid  price  \
# 2827  https://www.udemy.com/learn-html5-programming-...    False      0
# 3032  https://www.udemy.com/coding-for-entrepreneurs...    False      0
# 3230  https://www.udemy.com/the-web-developer-bootcamp/     True    200
# 2783  https://www.udemy.com/build-your-first-website...    False      0
# 3232  https://www.udemy.com/the-complete-web-develop...     True    200
#
#       num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
df.sort_values(by = 'num_subscribers' , ascending = True).head(5)
# Out:
#      course_id                                       course_title  \
# 885    1032648                               beginning accounting
# 456    1247992  Introduction to Project Management for Finance...
# 457    1251582              Best Practices in Corporate Budgeting
# 458    1258666                Financial Statement Auditing Cycles
# 459    1168172       Case studies on credit appraisal for bankers
#
#                                                    url  is_paid  price  \
# 885        https://www.udemy.com/beginning_accounting/     True     20
# 456  https://www.udemy.com/introduction-to-project-...     True     50
# 457  https://www.udemy.com/best-practices-corporate...     True     50
# 458  https://www.udemy.com/financial-statement-audi...     True     50
# 459  https://www.udemy.com/case-studies-on-credit-a...     True     20
#
#      num_subscribers  num_reviews  num_lectures               level  \
# 885                0            0            12  Intermediate Level
# ...

# %%
df[(df.subject == 'Graphic Design' ) & (df.price > 100)]
# Out:
#       course_id                                       course_title  \
# 1195     880202           Anatomy and Figure Drawing for Beginners
# 1197    1117796  Typographic Logo Design in Illustrator - Begin...
# 1199     595876  Logo Design in Adobe Illustrator - for Beginne...
# 1200    1216132  Learn Adobe Illustrator: Semi-Automatic Mandal...
# 1201    1145736  Create Professional Looking Infographics With ...
# ...         ...                                                ...
# 1758     632702  Adobe Suite : Unleash your creativity & benefi...
# 1765     876444  Inkscape 101 for Beginners - Design Vector Gra...
# 1769    1240730                Architectural Drawing For Creatives
# 1770     651014                Adobe Photoshop (Complete Beginner)
# 1776     489114  The Complete Video Production Guide - Learn To...
#
#                                                     url  is_paid  price  \
# 1195  https://www.udemy.com/anatomy-and-figure-drawi...     True    150
# ...

# %%
df[df.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!
# 41      1035472  Python for Finance: Investment Fundamentals & ...
# 147     1070886         Python Algo Trading: FX Trading with Oanda
# 334      815482               Stock Technical Analysis with Python
# 536      529828                     Python for Trading & Investing
# 762     1088656          Quantitative Trading Analysis with Python
# 863      902888          Investment Portfolio Analysis with Python
# 1682     546848  Learn to code in Python and learn Adobe Photos...
# 2497      16646                        Web Programming with Python
# 2528     391546        Learn Python and Django: Payment Processing
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...
# ...

# %%
plt.figure(figsize = (10,8))
ax = sns.countplot( x = 'level' , data = df , hue = 'subject')
for bar in ax.containers:
    ax.bar_label(bar)

# %%
plt.figure(figsize = (10,8))
ax = sns.countplot(x = 'subject' , data = df , hue = 'is_paid')
for bar in ax.containers:
    ax.bar_label(bar)

# %%
a = df.groupby(['subject'] , as_index = False).num_subscribers.sum().sort_values(by ='num_subscribers' ,ascending = False)
a
# Out:
#                subject  num_subscribers
# 3      Web Development          7980572
# 0     Business Finance          1868711
# 1       Graphic Design          1063148
# 2  Musical Instruments           846689

# %%
sns.barplot(x = 'subject' , y = 'num_subscribers' , data = a , hue = 'num_subscribers')
# Out:
# <Axes: xlabel='subject', ylabel='num_subscribers'>

# %%
plt.figure(figsize = (10,8))
b = df.groupby(['level' , 'subject'] , as_index = False).num_subscribers.sum()
sns.barplot(x = 'level' , y = 'num_subscribers' , data = b , hue = 'subject' )
# Out:
# <Axes: xlabel='level', ylabel='num_subscribers'>

# %%
a1 = df.groupby(['subject' , 'level'] ).num_subscribers.sum() 
a1
# Out:
# subject              level
# Business Finance     All Levels            1047208
#                      Beginner Level         647007
#                      Expert Level            30146
#                      Intermediate Level     144350
# Graphic Design       All Levels             688332
#                      Beginner Level         315757
#                      Expert Level             1008
#                      Intermediate Level      58051
# Musical Instruments  All Levels             328170
#                      Beginner Level         429030
#                      Expert Level             5431
#                      Intermediate Level      84058
# Web Development      All Levels            4851366
#                      Beginner Level        2660049
#                      Expert Level            13611
#                      Intermediate Level     455546
# Name: num_subscribers, dtype: int64

# %%
df.dtypes
# Out:
# course_id                int64
# course_title            object
# url                     object
# is_paid                   bool
# price                    int64
# num_subscribers          int64
# num_reviews              int64
# num_lectures             int64
# level                   object
# content_duration       float64
# published_timestamp     object
# subject                 object
# dtype: object

# %%
df.groupby('subject').agg({'content_duration' : 'max' , 'num_subscribers' : 'max' , 'num_lectures' : 'mean'})
# Out:
#                      content_duration  num_subscribers  num_lectures
# subject
# Business Finance                 71.5            65576     32.430962
# Graphic Design                   78.5            53851     32.054726
# Musical Instruments              38.0           101154     38.316176
# Web Development                  76.5           268923     52.817500

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df[["Year" , "month" , "Time"]] = df['published_timestamp'].str.split("-" ,n =2 , expand = True )

# %%
df
# Out:
#       course_id                                       course_title  \
# 0       1070968                 Ultimate Investment Banking Course
# 1       1113822  Complete GST Course & Certification - Grow You...
# 2       1006314  Financial Modeling for Business Analysts and C...
# 3       1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4       1011058       How To Maximize Your Profits Trading Options
# ...         ...                                                ...
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 0     https://www.udemy.com/ultimate-investment-bank...     True    200
# ...

# %%
df.head()
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level  \
# 0             2147           23            51          All Levels
# ...

# %%
df.groupby(['Year' , 'subject' ]).course_title.count()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Business Finance         6
#       Graphic Design          10
#       Musical Instruments     10
#       Web Development         19
# 2013  Business Finance        84
#       Graphic Design          23
#       Musical Instruments     39
#       Web Development         56
# 2014  Business Finance       192
#       Graphic Design          66
#       Musical Instruments    120
#       Web Development        113
# 2015  Business Finance       339
#       Graphic Design         168
#       Musical Instruments    171
#       Web Development        336
# 2016  Business Finance       349
#       Graphic Design         181
#       Musical Instruments    228
#       Web Development        448
# 2017  Business Finance       225
#       Graphic Design         155
#       Musical Instruments    112
#       Web Development        223
# Name: course_title, dtype: int64

# %%
plt.figure(figsize = (10 , 10))
ax = sns.countplot(x = 'Year' , data = df , hue = 'subject')
for bars in ax.containers:
    ax.bar_label(bars)
